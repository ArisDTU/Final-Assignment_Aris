# %%
import pandas as pd                # importing pandas package for data exploration
import geopandas as gpd            # importing geopandas for spatial operations
import urllib.request              # importing mpdule to open URLs
import zipfile                     # import module to read ZIP archive files
import os

# %%
## GETTING THE DATA

# downloading zip file with data, extract it and remove the zip file afterwards 

### ATTENTION!! THIS WILL AUTOMATICALLY DOWNLOAD THE DATA AND STORE IT IN YOUR DIRECTORY (8 files/572 KB) ###

# if the downloadlink does not work anymore, please contact arith@aqua.dtu.dk

urllib.request.urlretrieve("https://www.dropbox.com/s/ywsdhrrnsbni2wu/01_Spatial%20Autocorrelation.zip?dl=1", "01_Spatial Autocorrelation.zip")
zf = zipfile.ZipFile("01_Spatial Autocorrelation.zip")
zf.extractall()
zf.close()
os.remove("01_Spatial Autocorrelation.zip") # clean up

# %%
# reading and defining data frames from csv and from shp files

df_csv = pd.read_csv('under5mortality.csv')
df_shp = gpd.read_file('ne_110m_admin_0_countries.shp')

# %%
# changing column name ISO_A3 of shapefile into ISO in order to match column name in csv (needed to merge both dataframes)

df_shp.rename(columns={'ISO_A3':'ISO'}, 
                 inplace=True)

# %%
# performing left join of dataframes

df_new = pd.merge(df_csv, df_shp, on='ISO', how='left')

# %%
# (optional) saving merged dataframe into csv

df_new.to_csv('df_new.csv')

# %%
# showing merged dataframe

df_new
# Out:
#      Unnamed: 0  ISO                                  Name  ChildMortality  \
# 0             1  AFG                           Afghanistan            67.9
# 1             4  ALB                               Albania             8.8
# 2             7  DZA                               Algeria            24.0
# 3            10  AND                               Andorra             3.3
# 4            13  AGO                                Angola            81.1
# ..          ...  ...                                   ...             ...
# 191         574  VEN  Venezuela (Bolivarian Republic of)**            30.9
# 192         577  VNM                              Viet Nam            20.9
# 193         580  YEM                                 Yemen            55.4
# 194         583  ZMB                                Zambia            60.0
# 195         586  ZWE                              Zimbabwe            50.3
#
#           featurecla  scalerank  LABELRANK   SOVEREIGNT SOV_A3  ADM0_DIF  ...  \
# 0    Admin-0 country        1.0        3.0  Afghanistan    AFG       0.0  ...
# 1    Admin-0 country        1.0        6.0      Albania    ALB       0.0  ...
# 2    Admin-0 country        1.0        3.0      Algeria    DZA       0.0  ...
# 3                NaN        NaN        NaN          NaN    NaN       NaN  ...
# 4    Admin-0 country        1.0        3.0       Angola    AGO       0.0  ...
# ..               ...        ...        ...          ...    ...       ...  ...
# 191  Admin-0 country        1.0        3.0    Venezuela    VEN       0.0  ...
# 192  Admin-0 country        1.0        2.0      Vietnam    VNM       0.0  ...
# 193  Admin-0 country        1.0        3.0        Yemen    YEM       0.0  ...
# 194  Admin-0 country        1.0        3.0       Zambia    ZMB       0.0  ...
# 195  Admin-0 country        1.0        3.0     Zimbabwe    ZWE       0.0  ...
#
#      NAME_KO      NAME_NL     NAME_PL      NAME_PT     NAME_RU      NAME_SV  \
# 0     아프가니스탄  Afghanistan  Afganistan  Afeganistão  Афганистан  Afghanistan
# 1       알바니아      Albanië     Albania      Albânia     Албания     Albanien
# 2        알제리     Algerije    Algieria      Argélia       Алжир     Algeriet
# 3        NaN          NaN         NaN          NaN         NaN          NaN
# 4        앙골라       Angola      Angola       Angola      Ангола       Angola
# ..       ...          ...         ...          ...         ...          ...
# 191    베네수엘라    Venezuela   Wenezuela    Venezuela   Венесуэла    Venezuela
# 192      베트남      Vietnam     Wietnam     Vietname     Вьетнам      Vietnam
# 193       예멘        Jemen       Jemen        Iémen       Йемен        Jemen
# 194      잠비아       Zambia      Zambia       Zâmbia      Замбия       Zambia
# 195     짐바브웨     Zimbabwe    Zimbabwe     Zimbábue    Зимбабве     Zimbabwe
#
#         NAME_TR      NAME_VI NAME_ZH  \
# 0    Afganistan  Afghanistan     阿富汗
# 1    Arnavutluk      Albania   阿尔巴尼亚
# 2       Cezayir      Algérie   阿尔及利亚
# 3           NaN          NaN     NaN
# 4        Angola       Angola     安哥拉
# ..          ...          ...     ...
# 191   Venezuela    Venezuela    委內瑞拉
# 192     Vietnam     Việt Nam      越南
# 193       Yemen        Yemen      也门
# 194     Zambiya       Zambia     赞比亚
# 195    Zimbabve     Zimbabwe     辛巴威
#
#                                               geometry
# 0    POLYGON ((66.51861 37.36278, 67.07578 37.35614...
# 1    POLYGON ((21.02004 40.84273, 20.99999 40.58000...
# 2    POLYGON ((-8.68440 27.39574, -8.66512 27.58948...
# 3                                                 None
# 4    MULTIPOLYGON (((12.99552 -4.78110, 12.63161 -4...
# ..                                                 ...
# 191  POLYGON ((-60.73357 5.20028, -60.60118 4.91810...
# 192  POLYGON ((104.33433 10.48654, 105.19991 10.889...
# 193  POLYGON ((52.00001 19.00000, 52.78218 17.34974...
# 194  POLYGON ((30.74001 -8.34001, 31.15775 -8.59458...
# 195  POLYGON ((31.19141 -22.25151, 30.65987 -22.151...
#
# [196 rows x 98 columns]
